# %% [markdown]
# References: https://www.tensorflow.org/recommenders/examples/basic_ranking

# %% [markdown]
# # **RecSys Model 1: Ranking**

# %% [markdown]
# Real-world recommender systems are often composed of two stages:
#
# 1. **The retrieval stage** is responsible for selecting an initial set of hundreds of candidates from all possible candidates. The main objective of this model is to efficiently weed out all candidates that the user is not interested in. Because the retrieval model may be dealing with millions of candidates, it has to be computationally efficient.
# 2. **The ranking stage** takes the outputs of the retrieval model and fine-tunes them to select the best possible handful of recommendations. Its task is to narrow down the set of items the user may be interested in to a shortlist of likely candidates.
#
# We're going to focus on the second stage, ranking.

# %% [markdown]
# ## Imports

# %%
# Temporary solution for a bug in the implementation of the tfrs.layers.factorized_top_k module.
# https://github.com/tensorflow/recommenders/issues/712#issuecomment-2041163592

# !pip uninstall tensorflow -y
# !pip uninstall tensorflow-recommenders -y
#!pip uninstall tensorflow-datasets -y


import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
# Out:
# Found existing installation: tensorflow 2.17.1
# Uninstalling tensorflow-2.17.1:
#   Successfully uninstalled tensorflow-2.17.1
# WARNING: Skipping tensorflow-recommenders as it is not installed.

# %%
# !pip install -q tensorflow==2.17
# !pip install -q tensorflow-recommenders==0.7.3

#!pip install -q --upgrade tensorflow-datasets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 1.8 MB/s eta 0:00:00

# %%
import os
import pprint
import tempfile

from typing import Dict, Text

import numpy as np
import tensorflow as tf
#import tensorflow_datasets as tfds

#import json
import pandas as pd
from google.colab import drive

# %%
import tensorflow_recommenders as tfrs

# %%
print(tf.__version__)
# Out:
# 2.17.0

# %%
print(tfrs.__version__)
# Out:
# v0.7.3

# %% [markdown]
# # Importing and preprocessing the dataset

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
JSON_FILE = '/content/drive/My Drive/yelp_academic_dataset_business.json'

# %%
# Define the number of lines to read
#n_lines = 25000

# Read the specified number of lines into a list of dictionaries
#with open(JSON_FILE, "r") as file:
#    data = [json.loads(next(file)) for _ in range(n_lines)]

# Read the JSON lines file directly into a pandas DataFrame
df = pd.read_json(JSON_FILE, lines=True)

# Convert the list of dictionaries into a DataFrame
#df = pd.DataFrame(data)

# Display the first few rows
print(df.head())
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
print(len(df)) # total number of entries
# Out:
# 150346

# %%
# Filter rows where 'categories' is not null
df = df[df['categories'].notnull()]

# Select specific columns
df = df[['categories', 'business_id', 'stars']]

# Display the result
print(df.head())
# Out:
#                                           categories             business_id  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...  Pns2l4eNsfO8kk83dixA6A
# 1  Shipping Centers, Local Services, Notaries, Ma...  mpf3x-BjTdTEA3yCZrAYPw
# 2  Department Stores, Shopping, Fashion, Home & G...  tUFrWirKiKi_TAnsVWINQQ
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...  MTSW4McQd7CbVtyjqoe9mw
# 4                          Brewpubs, Breweries, Food  mWMc6_wTdE0EUBKIGXDVfA
#
#    stars
# 0    5.0
# 1    3.0
# 2    3.5
# 3    4.0
# 4    4.5

# %%
print(len(df))  # number of entries after removing 103 rows where 'categories' have null value
# Out:
# 150243

# %%
# Split 'categories' into a list of categories
df['categories'] = df['categories'].str.split(', ')

# Use explode to create a row for each category
df = df.explode('categories').reset_index(drop=True)

# Rename columns
df = df.rename(columns={'categories': 'category', 'business_id': 'employee_id', 'stars': 'overall_star'})

# Display the result
print(df.head())
# Out:
#                        category             employee_id  overall_star
# 0                       Doctors  Pns2l4eNsfO8kk83dixA6A           5.0
# 1  Traditional Chinese Medicine  Pns2l4eNsfO8kk83dixA6A           5.0
# 2         Naturopathic/Holistic  Pns2l4eNsfO8kk83dixA6A           5.0
# 3                   Acupuncture  Pns2l4eNsfO8kk83dixA6A           5.0
# 4              Health & Medical  Pns2l4eNsfO8kk83dixA6A           5.0

# %%
print(len(df)) # total number of entries after splitting 'categories'
# Out:
# 668592

# %%
# Create TensorFlow Dataset using tf.data
tf_dataset = tf.data.Dataset.from_tensor_slices((
    {'category': df['category'].astype(str).values,      # Ensure conversion to strings
    'employee_id': df['employee_id'].astype(str).values,   # Ensure conversion to strings
    'overall_star': df['overall_star'].astype(float).values}  # Ensure conversion to floats
))

# %%
# Displaying a sample from the TensorFlow Dataset using pprint
for x in tf_dataset.take(1).as_numpy_iterator():
    pprint.pprint(x)
# Out:
# {'category': b'Doctors',
#  'employee_id': b'Pns2l4eNsfO8kk83dixA6A',
#  'overall_star': 5.0}

# %% [markdown]
# Let's figure out **unique employee ids** and **categories** present in the data.
#
# This is important because we **need to be able to map the raw values of our categorical features to embedding vectors** in our models. To do that, we **need a vocabulary that maps a raw feature value to an integer in a contiguous range**: *this allows us to look up the corresponding embeddings in our embedding tables*.

# %%
# Extracting & processing data to build vocabularies (for category and employee embeddings)

employees = tf_dataset.map(lambda x: x["employee_id"])
categories = tf_dataset.map(lambda x: x["category"])

employee_ids = employees.batch(1_000)
category_names = categories.batch(1_000)

unique_employee_ids = np.unique(np.concatenate(list(employee_ids))) # vocabulary for the employee embeddings
unique_category_names = np.unique(np.concatenate(list(category_names))) # vocabulary for the category embeddings

# %%
unique_employee_ids[:10]
# Out:
# array([b'---kPU91CF4Lq2-WlRu9Lw', b'--0iUa4sNDFiZFrAdIWhZQ',
#        b'--30_8IhuyMHbSOcNWd6DQ', b'--7PUidqRWpRSpXebiyxTg',
#        b'--7jw19RH9JKXgFohspgQw', b'--8IbOsAAxjKRoYsBFL-PA',
#        b'--9osgUCSDUWUkoTLdvYhQ', b'--ARBQr1WMsTWiwOKOj-FQ',
#        b'--FWWsIwxRwuw9vIMImcQg', b'--FcbSxK1AoEtEAxOgBaCw'], dtype=object)

# %%
print(len(unique_employee_ids))
# Out:
# 150243

# %%
unique_category_names[:10]
# Out:
# array([b'& Probates', b'3D Printing', b'ATV Rentals/Tours', b'Acai Bowls',
#        b'Accessories', b'Accountants', b'Acne Treatment', b'Active Life',
#        b'Acupuncture', b'Addiction Medicine'], dtype=object)

# %%
print(len(unique_category_names))
# Out:
# 1311

# %%
# Split data into a training and evaluation set
# split the data by putting 80% of the ratings in the train set, and 20% in the test set.

tf.random.set_seed(42)
shuffled = tf_dataset.shuffle(100_000, seed=42, reshuffle_each_iteration=False)

# Since this model is used only to recreate the already obtained overall ratings by the employees who are already in the production database,
# it is suitable to use the test dataset also for training to recreate their ratings as well.
# Because no unseen data are given as input to this model under any circumstance, the model doesn't need to generalise to unseen data (unseen employees but not for unseen categories).
# Therefore, following code snippets to create train and test splits are ommitted during execution.

# But if there is an employee who hasn't worked and received a rating yet, that employee will never be appeared in the recommendations and will never be able to get a work for herself/himself.
# Therefore, it is necessary to make this model generalise to unseen data which will enable such employees to appear in the recommendations to receive job opportunities for themselves.
# (e.g. If employee A has 0 rating [not worked], and if we have use all the train and test dataset to train, then the model will recreate that employee A has 0 rating.
# But if we try to generalise the model using a test set [not used to train], there is a possibility that employee A might receive a bit higher rating by the model.
# This possiblity will enable that employee to appear in recommendations to get a work for herself/himself).
# But this is not our purpose of this model, we just need to recreate the overall ratings of all the employees in our database. This avoids the need for requesting employee ratings from the database for millions of employees for each request done by the customer.
# Therefore, following code snippets to create train and test splits are ommitted during execution.

#trainset_size = round(len(shuffled) * 0.8)
#testset_size = round(len(shuffled) * 0.2)

#train = shuffled.take(trainset_size)
#test = shuffled.skip(trainset_size).take(testset_size)

# %%
# Displaying a sample from the TensorFlow train Dataset using pprint
#for x in train.take(1).as_numpy_iterator():
#    pprint.pprint(x)

# %%
# Displaying a sample from the TensorFlow test Dataset using pprint
#for x in test.take(1).as_numpy_iterator():
#    pprint.pprint(x)

# %% [markdown]
# # Implementing a model

# %% [markdown]
# ## Architecture
#
# Ranking models do not face the same efficiency constraints as retrieval models do, and so we have a little bit more freedom in our choice of architectures.
#
# A model composed of multiple stacked dense layers is a relatively common architecture for ranking tasks. We can implement it as follows:

# %%
class RankingModel(tf.keras.Model):

  def __init__(self):
    super().__init__()
    embedding_dimension = 32 # The dimensionality of the category and employees embeddings/representations

    # Compute embeddings for category names.
    self.category_embeddings = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
        vocabulary=unique_category_names, mask_token=None),
      # We add an additional embedding to account for unknown tokens (to handle unseen or out-of-vocabulary (OOV) data.)
      tf.keras.layers.Embedding(len(unique_category_names) + 1, embedding_dimension)
    ])

    # Compute embeddings for employees.
    self.employee_embeddings = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
        vocabulary=unique_employee_ids, mask_token=None),
      # We add an additional embedding to account for unknown tokens (to handle unseen or out-of-vocabulary (OOV) data.)
      tf.keras.layers.Embedding(len(unique_employee_ids) + 1, embedding_dimension)
    ])

    # Compute predictions.
    self.ratings = tf.keras.Sequential([
      # Learn multiple dense layers.
      tf.keras.layers.Dense(256, activation="relu"),
      tf.keras.layers.Dense(64, activation="relu"),
      # Make rating predictions in the final layer.
      tf.keras.layers.Dense(1)
  ])

  def call(self, inputs):

    category_name, employee_id = inputs

    category_embedding = self.category_embeddings(category_name)
    employee_embedding = self.employee_embeddings(employee_id)

    return self.ratings(tf.concat([category_embedding, employee_embedding], axis=1))

# %% [markdown]
# This model takes user ids and movie titles, and outputs a predicted rating:

# %%
RankingModel()((["Electricians"], ["TCtVAiGDb05PyLe3v-zXDA"]))
# Out:
# <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[0.00085131]], dtype=float32)>

# %% [markdown]
# ## Loss and metrics
#
# The next component is the loss used to train our model. TFRS has several loss layers and tasks to make this easy.
#
# In this instance, we'll make use of the `Ranking` task object: a convenience wrapper that bundles together the loss function and metric computation.
#
# We'll use it together with the `MeanSquaredError` Keras loss in order to predict the ratings.

# %%
task = tfrs.tasks.Ranking(
  loss = tf.keras.losses.MeanSquaredError(),
  metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

# %% [markdown]
# The task itself is a Keras layer that takes true and predicted as arguments, and returns the computed loss. We'll use that to implement the model's training loop.

# %% [markdown]
# ## The full model
#
# We can now put it all together into a model. TFRS exposes a base model class (`tfrs.models.Model`) which streamlines bulding models: all we need to do is to set up the components in the `__init__` method, and implement the `compute_loss` method, taking in the raw features and returning a loss value.
#
# The base model will then take care of creating the appropriate training loop to fit our model.

# %%
class YelpModel(tfrs.models.Model):

  def __init__(self):
    super().__init__()
    self.ranking_model: tf.keras.Model = RankingModel()
    self.task: tf.keras.layers.Layer = tfrs.tasks.Ranking(
      loss = tf.keras.losses.MeanSquaredError(),
      metrics=[tf.keras.metrics.RootMeanSquaredError()]
    )

  def call(self, features: Dict[str, tf.Tensor]) -> tf.Tensor:
    return self.ranking_model(
        (features["category"], features["employee_id"]))

  def compute_loss(self, features: Dict[Text, tf.Tensor], training=False) -> tf.Tensor:
    labels = features.pop("overall_star")

    rating_predictions = self(features)

    # The task computes the loss and the metrics.
    return self.task(labels=labels, predictions=rating_predictions)

# %% [markdown]
# # Fitting and evaluating
#
# After defining the model, we can use standard Keras fitting and evaluation routines to fit and evaluate the model.
#
# Let's first instantiate the model.

# %%
model = YelpModel()
model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=0.1))

# %% [markdown]
# Then shuffle, batch, and cache the training and evaluation data.

# %%
# Since this model is used only to recreate the already obtained overall ratings by the employees who are already in the production database,
# it is suitable to use the test dataset also for training to recreate their ratings as well.
# Because no unseen data are given as input to this model under any circumstance, the model doesn't need to generalise to unseen data (unseen employees but not for unseen categories).
# We just need to recreate the overall ratings of all the employees in our database. This avoids the need for requesting employee ratings from the database for millions of employees for each request done by the customer.
# Therefore, following code snippets to create train and test splits are ommitted during execution.

#cached_train = train.shuffle(100_000).batch(8192).cache()
#cached_test = test.batch(4096).cache()

cached_train = shuffled.shuffle(100_000).batch(8192).cache()

# %% [markdown]
# Then train the  model:

# %%
model.fit(cached_train, epochs=200)
# Out:
# Epoch 1/200
# 82/82 [==============================] - 10s 97ms/step - root_mean_squared_error: 1.1591 - loss: 1.3356 - regularization_loss: 0.0000e+00 - total_loss: 1.3356
# Epoch 2/200
# 82/82 [==============================] - 5s 63ms/step - root_mean_squared_error: 0.9159 - loss: 0.8389 - regularization_loss: 0.0000e+00 - total_loss: 0.8389
# Epoch 3/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.9090 - loss: 0.8263 - regularization_loss: 0.0000e+00 - total_loss: 0.8263
# Epoch 4/200
# 82/82 [==============================] - 6s 69ms/step - root_mean_squared_error: 0.9042 - loss: 0.8175 - regularization_loss: 0.0000e+00 - total_loss: 0.8175
# Epoch 5/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.9012 - loss: 0.8122 - regularization_loss: 0.0000e+00 - total_loss: 0.8122
# Epoch 6/200
# 82/82 [==============================] - 7s 82ms/step - root_mean_squared_error: 0.8991 - loss: 0.8083 - regularization_loss: 0.0000e+00 - total_loss: 0.8083
# Epoch 7/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.8969 - loss: 0.8043 - regularization_loss: 0.0000e+00 - total_loss: 0.8043
# Epoch 8/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.8941 - loss: 0.7993 - regularization_loss: 0.0000e+00 - total_loss: 0.7993
# Epoch 9/200
# 82/82 [==============================] - 4s 52ms/step - root_mean_squared_error: 0.8903 - loss: 0.7924 - regularization_loss: 0.0000e+00 - total_loss: 0.7924
# Epoch 10/200
# 82/82 [==============================] - 4s 47ms/step - root_mean_squared_error: 0.8846 - loss: 0.7822 - regularization_loss: 0.0000e+00 - total_loss: 0.7822
# Epoch 11/200
# 82/82 [==============================] - 3s 43ms/step - root_mean_squared_error: 0.8758 - loss: 0.7666 - regularization_loss: 0.0000e+00 - total_loss: 0.7666
# Epoch 12/200
# 82/82 [==============================] - 5s 56ms/step - root_mean_squared_error: 0.8612 - loss: 0.7409 - regularization_loss: 0.0000e+00 - total_loss: 0.7409
# Epoch 13/200
# 82/82 [==============================] - 3s 43ms/step - root_mean_squared_error: 0.8374 - loss: 0.7002 - regularization_loss: 0.0000e+00 - total_loss: 0.7002
# Epoch 14/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.8039 - loss: 0.6451 - regularization_loss: 0.0000e+00 - total_loss: 0.6451
# Epoch 15/200
# 82/82 [==============================] - 5s 61ms/step - root_mean_squared_error: 0.7555 - loss: 0.5688 - regularization_loss: 0.0000e+00 - total_loss: 0.5688
# Epoch 16/200
# 82/82 [==============================] - 4s 48ms/step - root_mean_squared_error: 0.6869 - loss: 0.4698 - regularization_loss: 0.0000e+00 - total_loss: 0.4698
# Epoch 17/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.6143 - loss: 0.3756 - regularization_loss: 0.0000e+00 - total_loss: 0.3756
# Epoch 18/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.5372 - loss: 0.2869 - regularization_loss: 0.0000e+00 - total_loss: 0.2869
# Epoch 19/200
# 82/82 [==============================] - 5s 57ms/step - root_mean_squared_error: 0.4631 - loss: 0.2132 - regularization_loss: 0.0000e+00 - total_loss: 0.2132
# Epoch 20/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.4002 - loss: 0.1590 - regularization_loss: 0.0000e+00 - total_loss: 0.1590
# Epoch 21/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.3381 - loss: 0.1136 - regularization_loss: 0.0000e+00 - total_loss: 0.1136
# Epoch 22/200
# 82/82 [==============================] - 5s 66ms/step - root_mean_squared_error: 0.2887 - loss: 0.0827 - regularization_loss: 0.0000e+00 - total_loss: 0.0827
# Epoch 23/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.2470 - loss: 0.0605 - regularization_loss: 0.0000e+00 - total_loss: 0.0605
# Epoch 24/200
# 82/82 [==============================] - 5s 57ms/step - root_mean_squared_error: 0.2132 - loss: 0.0450 - regularization_loss: 0.0000e+00 - total_loss: 0.0450
# Epoch 25/200
# 82/82 [==============================] - 4s 51ms/step - root_mean_squared_error: 0.1836 - loss: 0.0335 - regularization_loss: 0.0000e+00 - total_loss: 0.0335
# Epoch 26/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.1578 - loss: 0.0247 - regularization_loss: 0.0000e+00 - total_loss: 0.0247
# Epoch 27/200
# 82/82 [==============================] - 4s 49ms/step - root_mean_squared_error: 0.1378 - loss: 0.0188 - regularization_loss: 0.0000e+00 - total_loss: 0.0188
# Epoch 28/200
# 82/82 [==============================] - 4s 49ms/step - root_mean_squared_error: 0.1209 - loss: 0.0145 - regularization_loss: 0.0000e+00 - total_loss: 0.0145
# Epoch 29/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.1063 - loss: 0.0112 - regularization_loss: 0.0000e+00 - total_loss: 0.0112
# Epoch 30/200
# 82/82 [==============================] - 4s 49ms/step - root_mean_squared_error: 0.0933 - loss: 0.0086 - regularization_loss: 0.0000e+00 - total_loss: 0.0086
# Epoch 31/200
# 82/82 [==============================] - 4s 48ms/step - root_mean_squared_error: 0.0844 - loss: 0.0071 - regularization_loss: 0.0000e+00 - total_loss: 0.0071
# Epoch 32/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0782 - loss: 0.0060 - regularization_loss: 0.0000e+00 - total_loss: 0.0060
# Epoch 33/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0702 - loss: 0.0049 - regularization_loss: 0.0000e+00 - total_loss: 0.0049
# Epoch 34/200
# 82/82 [==============================] - 6s 75ms/step - root_mean_squared_error: 0.0617 - loss: 0.0038 - regularization_loss: 0.0000e+00 - total_loss: 0.0038
# Epoch 35/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0565 - loss: 0.0032 - regularization_loss: 0.0000e+00 - total_loss: 0.0032
# Epoch 36/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0545 - loss: 0.0029 - regularization_loss: 0.0000e+00 - total_loss: 0.0029
# Epoch 37/200
# 82/82 [==============================] - 4s 48ms/step - root_mean_squared_error: 0.0511 - loss: 0.0026 - regularization_loss: 0.0000e+00 - total_loss: 0.0026
# Epoch 38/200
# 82/82 [==============================] - 4s 52ms/step - root_mean_squared_error: 0.0452 - loss: 0.0020 - regularization_loss: 0.0000e+00 - total_loss: 0.0020
# Epoch 39/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0421 - loss: 0.0018 - regularization_loss: 0.0000e+00 - total_loss: 0.0018
# Epoch 40/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0421 - loss: 0.0018 - regularization_loss: 0.0000e+00 - total_loss: 0.0018
# Epoch 41/200
# 82/82 [==============================] - 5s 66ms/step - root_mean_squared_error: 0.0403 - loss: 0.0016 - regularization_loss: 0.0000e+00 - total_loss: 0.0016
# Epoch 42/200
# 82/82 [==============================] - 4s 47ms/step - root_mean_squared_error: 0.0352 - loss: 0.0012 - regularization_loss: 0.0000e+00 - total_loss: 0.0012
# Epoch 43/200
# 82/82 [==============================] - 5s 59ms/step - root_mean_squared_error: 0.0324 - loss: 0.0010 - regularization_loss: 0.0000e+00 - total_loss: 0.0010
# Epoch 44/200
# 82/82 [==============================] - 4s 49ms/step - root_mean_squared_error: 0.0327 - loss: 0.0011 - regularization_loss: 0.0000e+00 - total_loss: 0.0011
# Epoch 45/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.0319 - loss: 0.0010 - regularization_loss: 0.0000e+00 - total_loss: 0.0010
# Epoch 46/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.0282 - loss: 7.9592e-04 - regularization_loss: 0.0000e+00 - total_loss: 7.9592e-04
# Epoch 47/200
# 82/82 [==============================] - 6s 70ms/step - root_mean_squared_error: 0.0258 - loss: 6.6529e-04 - regularization_loss: 0.0000e+00 - total_loss: 6.6529e-04
# Epoch 48/200
# 82/82 [==============================] - 4s 42ms/step - root_mean_squared_error: 0.0263 - loss: 6.8832e-04 - regularization_loss: 0.0000e+00 - total_loss: 6.8832e-04
# Epoch 49/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0261 - loss: 6.7641e-04 - regularization_loss: 0.0000e+00 - total_loss: 6.7641e-04
# Epoch 50/200
# 82/82 [==============================] - 5s 59ms/step - root_mean_squared_error: 0.0234 - loss: 5.4628e-04 - regularization_loss: 0.0000e+00 - total_loss: 5.4628e-04
# Epoch 51/200
# 82/82 [==============================] - 4s 48ms/step - root_mean_squared_error: 0.0214 - loss: 4.5813e-04 - regularization_loss: 0.0000e+00 - total_loss: 4.5813e-04
# Epoch 52/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0218 - loss: 4.7101e-04 - regularization_loss: 0.0000e+00 - total_loss: 4.7101e-04
# Epoch 53/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0218 - loss: 4.7083e-04 - regularization_loss: 0.0000e+00 - total_loss: 4.7083e-04
# Epoch 54/200
# 82/82 [==============================] - 6s 68ms/step - root_mean_squared_error: 0.0198 - loss: 3.9166e-04 - regularization_loss: 0.0000e+00 - total_loss: 3.9166e-04
# Epoch 55/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.0181 - loss: 3.2709e-04 - regularization_loss: 0.0000e+00 - total_loss: 3.2709e-04
# Epoch 56/200
# 82/82 [==============================] - 4s 53ms/step - root_mean_squared_error: 0.0184 - loss: 3.3582e-04 - regularization_loss: 0.0000e+00 - total_loss: 3.3582e-04
# Epoch 57/200
# 82/82 [==============================] - 4s 49ms/step - root_mean_squared_error: 0.0185 - loss: 3.3952e-04 - regularization_loss: 0.0000e+00 - total_loss: 3.3952e-04
# Epoch 58/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0170 - loss: 2.8858e-04 - regularization_loss: 0.0000e+00 - total_loss: 2.8858e-04
# Epoch 59/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0157 - loss: 2.4593e-04 - regularization_loss: 0.0000e+00 - total_loss: 2.4593e-04
# Epoch 60/200
# 82/82 [==============================] - 6s 69ms/step - root_mean_squared_error: 0.0158 - loss: 2.4892e-04 - regularization_loss: 0.0000e+00 - total_loss: 2.4892e-04
# Epoch 61/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.0160 - loss: 2.5366e-04 - regularization_loss: 0.0000e+00 - total_loss: 2.5366e-04
# Epoch 62/200
# 82/82 [==============================] - 5s 56ms/step - root_mean_squared_error: 0.0149 - loss: 2.2204e-04 - regularization_loss: 0.0000e+00 - total_loss: 2.2204e-04
# Epoch 63/200
# 82/82 [==============================] - 4s 48ms/step - root_mean_squared_error: 0.0138 - loss: 1.8972e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.8972e-04
# Epoch 64/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0139 - loss: 1.9194e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.9194e-04
# Epoch 65/200
# 82/82 [==============================] - 3s 43ms/step - root_mean_squared_error: 0.0141 - loss: 1.9655e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.9655e-04
# Epoch 66/200
# 82/82 [==============================] - 4s 53ms/step - root_mean_squared_error: 0.0132 - loss: 1.7463e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.7463e-04
# Epoch 67/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0123 - loss: 1.5259e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.5259e-04
# Epoch 68/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.0124 - loss: 1.5271e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.5271e-04
# Epoch 69/200
# 82/82 [==============================] - 6s 77ms/step - root_mean_squared_error: 0.0126 - loss: 1.5675e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.5675e-04
# Epoch 70/200
# 82/82 [==============================] - 4s 54ms/step - root_mean_squared_error: 0.0120 - loss: 1.4295e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.4295e-04
# Epoch 71/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0112 - loss: 1.2538e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.2538e-04
# Epoch 72/200
# 82/82 [==============================] - 5s 56ms/step - root_mean_squared_error: 0.0112 - loss: 1.2557e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.2557e-04
# Epoch 73/200
# 82/82 [==============================] - 4s 49ms/step - root_mean_squared_error: 0.0114 - loss: 1.2936e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.2936e-04
# Epoch 74/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0109 - loss: 1.1889e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.1889e-04
# Epoch 75/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0103 - loss: 1.0646e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.0646e-04
# Epoch 76/200
# 82/82 [==============================] - 6s 71ms/step - root_mean_squared_error: 0.0103 - loss: 1.0571e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.0571e-04
# Epoch 77/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0105 - loss: 1.0879e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.0879e-04
# Epoch 78/200
# 82/82 [==============================] - 4s 44ms/step - root_mean_squared_error: 0.0101 - loss: 1.0212e-04 - regularization_loss: 0.0000e+00 - total_loss: 1.0212e-04
# Epoch 79/200
# 82/82 [==============================] - 4s 49ms/step - root_mean_squared_error: 0.0096 - loss: 9.1539e-05 - regularization_loss: 0.0000e+00 - total_loss: 9.1539e-05
# Epoch 80/200
# 82/82 [==============================] - 4s 53ms/step - root_mean_squared_error: 0.0096 - loss: 9.1041e-05 - regularization_loss: 0.0000e+00 - total_loss: 9.1041e-05
# Epoch 81/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0097 - loss: 9.3994e-05 - regularization_loss: 0.0000e+00 - total_loss: 9.3994e-05
# Epoch 82/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0094 - loss: 8.8529e-05 - regularization_loss: 0.0000e+00 - total_loss: 8.8529e-05
# Epoch 83/200
# 82/82 [==============================] - 5s 67ms/step - root_mean_squared_error: 0.0090 - loss: 8.0820e-05 - regularization_loss: 0.0000e+00 - total_loss: 8.0820e-05
# Epoch 84/200
# 82/82 [==============================] - 3s 43ms/step - root_mean_squared_error: 0.0089 - loss: 7.9868e-05 - regularization_loss: 0.0000e+00 - total_loss: 7.9868e-05
# Epoch 85/200
# 82/82 [==============================] - 5s 56ms/step - root_mean_squared_error: 0.0091 - loss: 8.2277e-05 - regularization_loss: 0.0000e+00 - total_loss: 8.2277e-05
# Epoch 86/200
# 82/82 [==============================] - 4s 49ms/step - root_mean_squared_error: 0.0089 - loss: 7.8990e-05 - regularization_loss: 0.0000e+00 - total_loss: 7.8990e-05
# Epoch 87/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0085 - loss: 7.1972e-05 - regularization_loss: 0.0000e+00 - total_loss: 7.1972e-05
# Epoch 88/200
# 82/82 [==============================] - 4s 47ms/step - root_mean_squared_error: 0.0085 - loss: 7.1316e-05 - regularization_loss: 0.0000e+00 - total_loss: 7.1316e-05
# Epoch 89/200
# 82/82 [==============================] - 5s 64ms/step - root_mean_squared_error: 0.0086 - loss: 7.3906e-05 - regularization_loss: 0.0000e+00 - total_loss: 7.3906e-05
# Epoch 90/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0084 - loss: 7.0881e-05 - regularization_loss: 0.0000e+00 - total_loss: 7.0881e-05
# Epoch 91/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0081 - loss: 6.5576e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.5576e-05
# Epoch 92/200
# 82/82 [==============================] - 6s 71ms/step - root_mean_squared_error: 0.0081 - loss: 6.4696e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.4696e-05
# Epoch 93/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0082 - loss: 6.6884e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.6884e-05
# Epoch 94/200
# 82/82 [==============================] - 5s 58ms/step - root_mean_squared_error: 0.0081 - loss: 6.5296e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.5296e-05
# Epoch 95/200
# 82/82 [==============================] - 4s 50ms/step - root_mean_squared_error: 0.0077 - loss: 6.0074e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.0074e-05
# Epoch 96/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0077 - loss: 5.9393e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.9393e-05
# Epoch 97/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0079 - loss: 6.1972e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.1972e-05
# Epoch 98/200
# 82/82 [==============================] - 6s 70ms/step - root_mean_squared_error: 0.0078 - loss: 6.0236e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.0236e-05
# Epoch 99/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0075 - loss: 5.6126e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.6126e-05
# Epoch 100/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0074 - loss: 5.5343e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.5343e-05
# Epoch 101/200
# 82/82 [==============================] - 4s 44ms/step - root_mean_squared_error: 0.0076 - loss: 5.7636e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.7636e-05
# Epoch 102/200
# 82/82 [==============================] - 4s 49ms/step - root_mean_squared_error: 0.0076 - loss: 5.7102e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.7102e-05
# Epoch 103/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0073 - loss: 5.2678e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.2678e-05
# Epoch 104/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0072 - loss: 5.2025e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.2025e-05
# Epoch 105/200
# 82/82 [==============================] - 6s 69ms/step - root_mean_squared_error: 0.0074 - loss: 5.5024e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.5024e-05
# Epoch 106/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0074 - loss: 5.4189e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.4189e-05
# Epoch 107/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0071 - loss: 5.0464e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.0464e-05
# Epoch 108/200
# 82/82 [==============================] - 4s 45ms/step - root_mean_squared_error: 0.0071 - loss: 4.9716e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.9716e-05
# Epoch 109/200
# 82/82 [==============================] - 4s 52ms/step - root_mean_squared_error: 0.0073 - loss: 5.2706e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.2706e-05
# Epoch 110/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.0073 - loss: 5.3040e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.3040e-05
# Epoch 111/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0070 - loss: 4.8631e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.8631e-05
# Epoch 112/200
# 82/82 [==============================] - 5s 66ms/step - root_mean_squared_error: 0.0069 - loss: 4.7982e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.7982e-05
# Epoch 113/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0072 - loss: 5.2085e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.2085e-05
# Epoch 114/200
# 82/82 [==============================] - 5s 56ms/step - root_mean_squared_error: 0.0072 - loss: 5.2171e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.2171e-05
# Epoch 115/200
# 82/82 [==============================] - 4s 54ms/step - root_mean_squared_error: 0.0069 - loss: 4.8045e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.8045e-05
# Epoch 116/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0069 - loss: 4.7272e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.7272e-05
# Epoch 117/200
# 82/82 [==============================] - 3s 43ms/step - root_mean_squared_error: 0.0072 - loss: 5.1877e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.1877e-05
# Epoch 118/200
# 82/82 [==============================] - 5s 65ms/step - root_mean_squared_error: 0.0073 - loss: 5.3348e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.3348e-05
# Epoch 119/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0069 - loss: 4.7993e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.7993e-05
# Epoch 120/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0069 - loss: 4.7207e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.7207e-05
# Epoch 121/200
# 82/82 [==============================] - 6s 69ms/step - root_mean_squared_error: 0.0074 - loss: 5.3677e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.3677e-05
# Epoch 122/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0074 - loss: 5.5029e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.5029e-05
# Epoch 123/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.0070 - loss: 4.9393e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.9393e-05
# Epoch 124/200
# 82/82 [==============================] - 4s 46ms/step - root_mean_squared_error: 0.0069 - loss: 4.8292e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.8292e-05
# Epoch 125/200
# 82/82 [==============================] - 4s 55ms/step - root_mean_squared_error: 0.0075 - loss: 5.5893e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.5893e-05
# Epoch 126/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0077 - loss: 5.9035e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.9035e-05
# Epoch 127/200
# 82/82 [==============================] - 4s 52ms/step - root_mean_squared_error: 0.0071 - loss: 5.1336e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.1336e-05
# Epoch 128/200
# 82/82 [==============================] - 4s 55ms/step - root_mean_squared_error: 0.0071 - loss: 4.9899e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.9899e-05
# Epoch 129/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0078 - loss: 6.0085e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.0085e-05
# Epoch 130/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0080 - loss: 6.3057e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.3057e-05
# Epoch 131/200
# 82/82 [==============================] - 5s 62ms/step - root_mean_squared_error: 0.0074 - loss: 5.4423e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.4423e-05
# Epoch 132/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0072 - loss: 5.2163e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.2163e-05
# Epoch 133/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0080 - loss: 6.3286e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.3286e-05
# Epoch 134/200
# 82/82 [==============================] - 5s 59ms/step - root_mean_squared_error: 0.0083 - loss: 6.7971e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.7971e-05
# Epoch 135/200
# 82/82 [==============================] - 4s 48ms/step - root_mean_squared_error: 0.0075 - loss: 5.6578e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.6578e-05
# Epoch 136/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0073 - loss: 5.3279e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.3279e-05
# Epoch 137/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0082 - loss: 6.5943e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.5943e-05
# Epoch 138/200
# 82/82 [==============================] - 4s 54ms/step - root_mean_squared_error: 0.0084 - loss: 6.9434e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.9434e-05
# Epoch 139/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.0076 - loss: 5.7612e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.7612e-05
# Epoch 140/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0073 - loss: 5.2997e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.2997e-05
# Epoch 141/200
# 82/82 [==============================] - 6s 71ms/step - root_mean_squared_error: 0.0080 - loss: 6.4186e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.4186e-05
# Epoch 142/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0083 - loss: 6.8694e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.8694e-05
# Epoch 143/200
# 82/82 [==============================] - 5s 57ms/step - root_mean_squared_error: 0.0074 - loss: 5.5711e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.5711e-05
# Epoch 144/200
# 82/82 [==============================] - 4s 48ms/step - root_mean_squared_error: 0.0071 - loss: 5.0206e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.0206e-05
# Epoch 145/200
# 82/82 [==============================] - 3s 43ms/step - root_mean_squared_error: 0.0078 - loss: 6.0664e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.0664e-05
# Epoch 146/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.0080 - loss: 6.3667e-05 - regularization_loss: 0.0000e+00 - total_loss: 6.3667e-05
# Epoch 147/200
# 82/82 [==============================] - 6s 68ms/step - root_mean_squared_error: 0.0072 - loss: 5.2700e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.2700e-05
# Epoch 148/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.0068 - loss: 4.6744e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.6744e-05
# Epoch 149/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0074 - loss: 5.4541e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.4541e-05
# Epoch 150/200
# 82/82 [==============================] - 4s 48ms/step - root_mean_squared_error: 0.0077 - loss: 5.8737e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.8737e-05
# Epoch 151/200
# 82/82 [==============================] - 4s 50ms/step - root_mean_squared_error: 0.0070 - loss: 4.8582e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.8582e-05
# Epoch 152/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0065 - loss: 4.2784e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.2784e-05
# Epoch 153/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0071 - loss: 4.9726e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.9726e-05
# Epoch 154/200
# 82/82 [==============================] - 6s 68ms/step - root_mean_squared_error: 0.0073 - loss: 5.2827e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.2827e-05
# Epoch 155/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0067 - loss: 4.5389e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.5389e-05
# Epoch 156/200
# 82/82 [==============================] - 3s 43ms/step - root_mean_squared_error: 0.0063 - loss: 3.9770e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.9770e-05
# Epoch 157/200
# 82/82 [==============================] - 4s 49ms/step - root_mean_squared_error: 0.0067 - loss: 4.4794e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.4794e-05
# Epoch 158/200
# 82/82 [==============================] - 4s 53ms/step - root_mean_squared_error: 0.0070 - loss: 4.9110e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.9110e-05
# Epoch 159/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0065 - loss: 4.2330e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.2330e-05
# Epoch 160/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0061 - loss: 3.7178e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.7178e-05
# Epoch 161/200
# 82/82 [==============================] - 5s 56ms/step - root_mean_squared_error: 0.0065 - loss: 4.1986e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.1986e-05
# Epoch 162/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0068 - loss: 4.5514e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.5514e-05
# Epoch 163/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0064 - loss: 4.0722e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.0722e-05
# Epoch 164/200
# 82/82 [==============================] - 6s 69ms/step - root_mean_squared_error: 0.0059 - loss: 3.5617e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.5617e-05
# Epoch 165/200
# 82/82 [==============================] - 4s 44ms/step - root_mean_squared_error: 0.0063 - loss: 3.9336e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.9336e-05
# Epoch 166/200
# 82/82 [==============================] - 6s 70ms/step - root_mean_squared_error: 0.0067 - loss: 4.4176e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.4176e-05
# Epoch 167/200
# 82/82 [==============================] - 4s 44ms/step - root_mean_squared_error: 0.0063 - loss: 3.9456e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.9456e-05
# Epoch 168/200
# 82/82 [==============================] - 5s 57ms/step - root_mean_squared_error: 0.0059 - loss: 3.4548e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.4548e-05
# Epoch 169/200
# 82/82 [==============================] - 5s 55ms/step - root_mean_squared_error: 0.0062 - loss: 3.8562e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.8562e-05
# Epoch 170/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0066 - loss: 4.3002e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.3002e-05
# Epoch 171/200
# 82/82 [==============================] - 5s 57ms/step - root_mean_squared_error: 0.0063 - loss: 3.9632e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.9632e-05
# Epoch 172/200
# 82/82 [==============================] - 4s 54ms/step - root_mean_squared_error: 0.0058 - loss: 3.4354e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.4354e-05
# Epoch 173/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0062 - loss: 3.7776e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.7776e-05
# Epoch 174/200
# 82/82 [==============================] - 5s 58ms/step - root_mean_squared_error: 0.0067 - loss: 4.3899e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.3899e-05
# Epoch 175/200
# 82/82 [==============================] - 4s 51ms/step - root_mean_squared_error: 0.0063 - loss: 4.0099e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.0099e-05
# Epoch 176/200
# 82/82 [==============================] - 4s 44ms/step - root_mean_squared_error: 0.0059 - loss: 3.4562e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.4562e-05
# Epoch 177/200
# 82/82 [==============================] - 4s 48ms/step - root_mean_squared_error: 0.0062 - loss: 3.8659e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.8659e-05
# Epoch 178/200
# 82/82 [==============================] - 4s 52ms/step - root_mean_squared_error: 0.0067 - loss: 4.4795e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.4795e-05
# Epoch 179/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0065 - loss: 4.2062e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.2062e-05
# Epoch 180/200
# 82/82 [==============================] - 4s 44ms/step - root_mean_squared_error: 0.0059 - loss: 3.5615e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.5615e-05
# Epoch 181/200
# 82/82 [==============================] - 6s 70ms/step - root_mean_squared_error: 0.0063 - loss: 3.9322e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.9322e-05
# Epoch 182/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0069 - loss: 4.7679e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.7679e-05
# Epoch 183/200
# 82/82 [==============================] - 6s 70ms/step - root_mean_squared_error: 0.0066 - loss: 4.4150e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.4150e-05
# Epoch 184/200
# 82/82 [==============================] - 3s 42ms/step - root_mean_squared_error: 0.0060 - loss: 3.6890e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.6890e-05
# Epoch 185/200
# 82/82 [==============================] - 5s 55ms/step - root_mean_squared_error: 0.0064 - loss: 4.1365e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.1365e-05
# Epoch 186/200
# 82/82 [==============================] - 4s 51ms/step - root_mean_squared_error: 0.0071 - loss: 4.9875e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.9875e-05
# Epoch 187/200
# 82/82 [==============================] - 4s 44ms/step - root_mean_squared_error: 0.0069 - loss: 4.7267e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.7267e-05
# Epoch 188/200
# 82/82 [==============================] - 5s 55ms/step - root_mean_squared_error: 0.0062 - loss: 3.8585e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.8585e-05
# Epoch 189/200
# 82/82 [==============================] - 5s 60ms/step - root_mean_squared_error: 0.0065 - loss: 4.2328e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.2328e-05
# Epoch 190/200
# 82/82 [==============================] - 4s 44ms/step - root_mean_squared_error: 0.0073 - loss: 5.3077e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.3077e-05
# Epoch 191/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0070 - loss: 4.9394e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.9394e-05
# Epoch 192/200
# 82/82 [==============================] - 5s 63ms/step - root_mean_squared_error: 0.0063 - loss: 3.9693e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.9693e-05
# Epoch 193/200
# 82/82 [==============================] - 4s 49ms/step - root_mean_squared_error: 0.0066 - loss: 4.3682e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.3682e-05
# Epoch 194/200
# 82/82 [==============================] - 3s 41ms/step - root_mean_squared_error: 0.0074 - loss: 5.3750e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.3750e-05
# Epoch 195/200
# 82/82 [==============================] - 5s 62ms/step - root_mean_squared_error: 0.0072 - loss: 5.1141e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.1141e-05
# Epoch 196/200
# 82/82 [==============================] - 4s 48ms/step - root_mean_squared_error: 0.0063 - loss: 4.0225e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.0225e-05
# Epoch 197/200
# 82/82 [==============================] - 4s 43ms/step - root_mean_squared_error: 0.0065 - loss: 4.2687e-05 - regularization_loss: 0.0000e+00 - total_loss: 4.2687e-05
# Epoch 198/200
# 82/82 [==============================] - 5s 58ms/step - root_mean_squared_error: 0.0074 - loss: 5.3908e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.3908e-05
# Epoch 199/200
# 82/82 [==============================] - 7s 87ms/step - root_mean_squared_error: 0.0071 - loss: 5.0407e-05 - regularization_loss: 0.0000e+00 - total_loss: 5.0407e-05
# Epoch 200/200
# 82/82 [==============================] - 3s 43ms/step - root_mean_squared_error: 0.0062 - loss: 3.9450e-05 - regularization_loss: 0.0000e+00 - total_loss: 3.9450e-05

# %% [markdown]
# As the model trains, the loss is falling and the RMSE metric is improving.

# %% [markdown]
# Finally, we can evaluate our model on the test set:

# %%
# Since this model is used only to recreate the already obtained overall ratings by the employees who are already in the production database,
# it is suitable to use the test dataset also for training to recreate their ratings as well.
# Because no unseen data are given as input to this model under any circumstance, the model doesn't need to generalise to unseen data (unseen employees but not for unseen categories).
# We just need to recreate the overall ratings of all the employees in our database. This avoids the need for requesting employee ratings from the database for millions of employees for each request done by the customer.
# Therefore, following code snippet to test the model is ommitted during execution.

#model.evaluate(cached_test, return_dict=True)

# %% [markdown]
# The lower the RMSE metric, the more accurate our model is at predicting ratings.

# %% [markdown]
# # Testing the ranking model
#
# Now we can test the ranking model by computing predictions for a set of employees and then rank these employees based on the predictions:

# %%
test_ratings = {}
test_employee_ids = ["z7otfCcjH3Awwck7nsEEqQ", "QL3xkxLAe788em3_3eC4LQ", "TCtVAiGDb05PyLe3v-zXDA", "1xeRysU0YYOnpy-5_3ySag", "HTHUzTl-vDhEcbh7bZfhIg"]
for employee_id in test_employee_ids:
  test_ratings[employee_id] = model({
      "category": np.array(["Electricians"]),
      "employee_id": np.array([employee_id])
  })

print("Ratings:")
for employee_id, score in sorted(test_ratings.items(), key=lambda x: x[1], reverse=True):
  print(f"{employee_id}: {score}")
# Out:
# Ratings:
# TCtVAiGDb05PyLe3v-zXDA: [[4.507906]]
# QL3xkxLAe788em3_3eC4LQ: [[4.004672]]
# 1xeRysU0YYOnpy-5_3ySag: [[4.0038233]]
# HTHUzTl-vDhEcbh7bZfhIg: [[3.5086079]]
# z7otfCcjH3Awwck7nsEEqQ: [[3.508493]]

# %% [markdown]
# # Exporting for serving
#
# The model can be easily exported for serving:

# %%
tf.saved_model.save(model, "export")

# %% [markdown]
# We can now load it back and perform predictions:

# %%
loaded = tf.saved_model.load("export")

loaded({"category": np.array(["Electricians"]), "employee_id": ["DD4gTG-FeG_nneXcexJ2eg"]}).numpy()
# Out:
# array([[3.00802]], dtype=float32)

# %%
# Define the folder path for saving the model
save_dir = '/content/drive/My Drive/Colab Notebooks/Saved Models'
#save_dir = '/content/Saved Model'

# Ensure the folder exists
os.makedirs(save_dir, exist_ok=True)

# Path to save the model
model_path = os.path.join(save_dir, "recsys_model_one_ranking")

# Save the model
tf.saved_model.save(
    model,
    model_path
)

# Load the model back
loaded = tf.saved_model.load(model_path)

# Pass a category name and employee id to get rating predictions
rating = loaded({"category": np.array(["Electricians"]), "employee_id": ["DD4gTG-FeG_nneXcexJ2eg"]}).numpy()

print("Rating predictions:")
print(f"DD4gTG-FeG_nneXcexJ2eg: {rating[0]}")
# Out:
# Rating predictions:
# DD4gTG-FeG_nneXcexJ2eg: [3.00802]
